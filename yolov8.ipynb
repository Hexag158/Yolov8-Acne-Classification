# %%
from ultralytics import YOLO
import torch

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
print(torch.cuda.is_available())
torch.cuda.device_count()
print(torch.cuda.get_device_name(0))
torch.cuda.set_device(0)
print(torch.cuda.current_device())
print(torch.cuda.get_device_name())
# Out:
# True
# NVIDIA GeForce RTX 3050 Laptop GPU
# 0
# NVIDIA GeForce RTX 3050 Laptop GPU

# %%
model = YOLO('yolov8n-cls.yaml')  # initialize
#model = YOLO('yolov8n_cls.yaml').load('yolov8n.pt')  # initialize
model.to ('cuda:0')
model.train(data='D:\DemoYolov8\data', epochs=10, imgsz=100,device='cuda:0')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
# ...

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt


results_path = './runs/classify/train5/results.csv'

results = pd.read_csv(results_path)

plt.figure()
plt.plot(results['                  epoch'], results['             train/loss'], label='train loss')
plt.plot(results['                  epoch'], results['               val/loss'], label='val loss', c='red')
plt.grid()
plt.title('Loss vs epochs')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()


plt.figure()
plt.plot(results['                  epoch'], results['  metrics/accuracy_top1'] * 100)
plt.grid()
plt.title('Validation accuracy vs epochs')
plt.ylabel('accuracy (%)')
plt.xlabel('epochs')

plt.show()

# %%
model = YOLO('./runs/classify/train6/weights/best.pt') # load a pretrained model (recommended for training)
# Resume training
model.to ('cuda:0')
model.train(data='D:\DemoYolov8\data', epochs=50, resume=True, imgsz=100,device='cuda:0')
# Out:
# New https://pypi.org/project/ultralytics/8.0.141 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.87  Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
results_path = './runs/classify/train5/results.csv'

results = pd.read_csv(results_path)

plt.figure()
plt.plot(results['                  epoch'], results['             train/loss'], label='train loss')
plt.plot(results['                  epoch'], results['               val/loss'], label='val loss', c='red')
plt.grid()
plt.title('Loss vs epochs')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()


plt.figure()
plt.plot(results['                  epoch'], results['  metrics/accuracy_top1'] * 100)
plt.grid()
plt.title('Validation accuracy vs epochs')
plt.ylabel('accuracy (%)')
plt.xlabel('epochs')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\DemoYolov8\yolov8.ipynb Cell 7 in 3
#       <a href='vscode-notebook-cell:/d%3A/DemoYolov8/yolov8.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> results_path = './runs/classify/train5/results.csv'
# ----> <a href='vscode-notebook-cell:/d%3A/DemoYolov8/yolov8.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> results = pd.read_csv(results_path)
#       <a href='vscode-notebook-cell:/d%3A/DemoYolov8/yolov8.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> plt.figure()
#       <a href='vscode-notebook-cell:/d%3A/DemoYolov8/yolov8.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> plt.plot(results['                  epoch'], results['             train/loss'], label='train loss')
#
# NameError: name 'pd' is not defined
